# %% [markdown]
# # MCP

# %%
from mcp import stdio_client, StdioServerParameters
from strands import Agent
from strands.tools.mcp import MCPClient

# %%
message = "strands-agent가 무엇인가요?"

# %% [markdown]
# - `Strands Agent`에 대해서 물어 보았습니다.
# - MCP/tool이 없는 상태에서, 최신정보인 strands agent에 대해서 엉뚱한 답변으로 "할루시네이션"이 발생하는 것을 볼 수 있습니다.

# %%
agent_no_tool = Agent()
agent_no_tool(message)
# Out:
# Strands-agent는 AI 모델(예: GPT-4)의 능력을 강화하기 위해 설계된 프레임워크입니다. 이것은 AI가 복잡한 작업을 처리할 때 더 체계적으로 생각하고 추론할 수 있도록 돕는 도구입니다.
#
# 주요 특징으로는:
#
# 1. 복잡한 질문을 여러 하위 작업으로 분해하는 능력
# 2. 단계적 추론 과정을 통한 문제 해결
# 3. 자체 검토 및 수정 기능
# 4. 여러 사고 경로를 탐색하는 능력
#
# 이 프레임워크는 AI 시스템이 복잡한 문제에 더 신중하고 논리적으로 접근하게 함으로써, 특히 추론이 필요한 작업에서 성능을 향상시키는 것을 목표로 합니다.
# AgentResult(stop_reason='end_turn', message={'role': 'assistant', 'content': [{'text': 'Strands-agent는 AI 모델(예: GPT-4)의 능력을 강화하기 위해 설계된 프레임워크입니다. 이것은 AI가 복잡한 작업을 처리할 때 더 체계적으로 생각하고 추론할 수 있도록 돕는 도구입니다.\n\n주요 특징으로는:\n\n1. 복잡한 질문을 여러 하위 작업으로 분해하는 능력\n2. 단계적 추론 과정을 통한 문제 해결\n3. 자체 검토 및 수정 기능\n4. 여러 사고 경로를 탐색하는 능력\n\n이 프레임워크는 AI 시스템이 복잡한 문제에 더 신중하고 논리적으로 접근하게 함으로써, 특히 추론이 필요한 작업에서 성능을 향상시키는 것을 목표로 합니다.'}]}, metrics=EventLoopMetrics(cycle_count=1, tool_metrics={}, cycle_durations=[7.095181226730347], traces=[<strands.telemetry.metrics.Trace object at 0x125b0a910>], accumulated_usage={'inputTokens': 20, 'outputTokens': 295, 'totalTokens': 315}, accumulated_metrics={'latencyMs': 6059}), state={})

# %% [markdown]
# # MCP - aws-documentation
# - aws 문서를 검색할 수 있는 mcp를 사용하여 tool을 가져왔습니다.
# - 이제 agent는 aws 문서를 탐색하는 tool을 사용하여 답변 할 수 있습니다.
# - tool/mcp를 사용하여, 1번의 검색 2번의 문서읽기를 사용하였고, 결과적으로 `strands agent`에 대한 정확한 답변을 얻는 것을 확인 할 수 있습니다.

# %%
# For macOS/Linux:
stdio_mcp_client = MCPClient(lambda: stdio_client(
    StdioServerParameters(
        command="uvx", 
        args=["awslabs.aws-documentation-mcp-server@latest"]
    )
))


with stdio_mcp_client:
    tools = stdio_mcp_client.list_tools_sync() # get tools from MCP
    agent = Agent(tools=tools)
    agent(message)
# Out:
# 안녕하세요! "strands-agent"에 대한 정보를 찾아드리겠습니다. 이것이 AWS의 특정 서비스나 기능인지 확인하기 위해 AWS 문서를 검색해 보겠습니다.
# Tool #1: search_documentation
# 검색 결과 중 "Strands Agents"에 대한 직접적인 문서를 발견했습니다. 이 문서를 자세히 살펴보겠습니다.
# Tool #2: read_documentation
# 더 많은 정보를 얻기 위해 계속 읽어보겠습니다.
# Tool #3: read_documentation
# 이제 strands-agent에 대한 충분한 정보를 얻었습니다. 내용을 종합하여 답변드리겠습니다.
#
# ## Strands Agent 란?
#
# Strands Agents는 AWS에서 처음 출시한 오픈소스 SDK(Software Development Kit)로, 자율적인 AI 에이전트를 구축하기 위한 프레임워크입니다. 모델 중심(model-first) 접근 방식을 채택하여 설계되었으며, AWS 서비스와 원활하게 연동되면서도 제3자 구성 요소와의 통합이 가능하도록 유연한 확장성을 제공합니다.
#
# ### 주요 특징:
#
# 1. **모델 중심 설계**: 기반 모델(foundation model)이 에이전트 지능의 핵심이라는 개념을 바탕으로 설계되어 정교한 자율 추론이 가능합니다.
#
# 2. **MCP(Model Context Protocol) 통합**: 일관된 자율 작동을 위해 LLM에 표준화된 컨텍스트를 제공하는 MCP를 기본적으로 지원합니다.
#
# 3. **AWS 서비스 통합**: Amazon Bedrock, AWS Lambda, AWS Step Functions 등 다양한 AWS 서비스와 원활하게 연결되어 종합적인 자율 워크플로우를 구현할 수 있습니다.
#
# 4. **다양한 기반 모델 지원**: Anthropic Claude, Amazon Nova(Premier, Pro, Lite, Micro) 등 Amazon Bedrock에서 제공하는 다양한 기반 모델을 지원하여 다양한 자율 추론 능력을 최적화할 수 있습니다.
#
# 5. **LLM API 통합**: Amazon Bedrock, OpenAI 등 다양한 LLM 서비스 인터페이스와 유연하게 통합할 수 있습니다.
#
# 6. **멀티모달 기능**: 텍스트, 음성, 이미지 처리를 포함한 여러 모달리티를 지원하여 포괄적인 자율 에이전트 상호작용이 가능합니다.
#
# 7. **도구 생태계**: AWS 서비스 상호작용을 위한 풍부한 도구 세트를 제공하며, 자율 기능을 확장하기 위한 커스텀 도구를 추가할 수 있습니다.
#
# ### 활용 사례:
#
# Strands Agents는 다음과 같은 상황에서 특히 유용합니다:
# - AWS 인프라를 기반으로 구축하는 조직으로, 자율 워크플로우를 위한 AWS 서비스와의 기본 통합이 필요한 경우
# - 프로덕션 자율 시스템을 위한 엔터프라이즈급 보안, 확장성 및 규정 준수 기능이 필요한 팀
# - 특수 자율 작업을 위해 다양한 제공업체에서 모델 선택의 유연성이 필요한 프로젝트
# - 기존 AWS 워크플로우 및 리소스와의 긴밀한 통합이 필요한 엔드투엔드 자율 프로세스 사용 사례
#
# ### 실제 사용 사례:
#
# AWS Transform for .NET은 Strands Agents를 사용하여 애플리케이션 현대화 기능을 제공합니다. 이 프로덕션 서비스는 여러 전문 자율 에이전트를 사용하여 레거시 .NET 애플리케이션을 분석하고, 현대화 전략을 계획하며, 인간의 개입 없이 클라우드 네이티브 아키텍처로 코드 변환을 실행합니다.
#
# 자세한 내용은 [Strands Agents 공식 문서](https://strandsagents.com/)에서 확인할 수 있습니다.

# %% [markdown]
# # 외부 MCP
# - DuckDuckGo / web-scout-mcp
#     - 참조 : https://github.com/pinkpixel-dev/web-scout-mcp
#     - 로컬 설치 : `npm install @pinkpixel/web-scout-mcp`
#     - 다음은 표준 Mcp Client 정보 입니다. 여기에서, strands는 command와 args 정보를 취하여 사용할 수 있습니다.
#     - mcp client 설정 정보
# ```
# {
#   "mcpServers": {
#     "web-scout": {
#       "command": "npx",
#       "args": [
#         "-y",
#         "@pinkpixel/web-scout-mcp"
#       ]
#     }
#   }
# }
# ```

# %%
stdio_external_mcp_client = MCPClient(lambda: stdio_client(
    StdioServerParameters(
        command="npx", 
        args=["-y", "@pinkpixel/web-scout-mcp"]
    )
))


with stdio_external_mcp_client:
    tools = stdio_external_mcp_client.list_tools_sync() # get tools from MCP
    print(" ## MCP Tools : ",tools)
    agent = Agent(tools=tools)
    results = agent("최신 AI 뉴스를 3개 검색 하고, 최종 요약해줘. 이 때 참조한 출저 url을 함께 표기 해.")
# Out:
#  ## MCP Tools :  [<strands.tools.mcp.mcp_agent_tool.MCPAgentTool object at 0x126c35010>, <strands.tools.mcp.mcp_agent_tool.MCPAgentTool object at 0x12749c4d0>]
# 최신 AI 뉴스를 검색하고 요약해드리겠습니다. DuckDuckGo 검색 엔진을 통해 최신 AI 뉴스를 검색하겠습니다.
# Tool #1: DuckDuckGoWebSearch
# 이제 각 뉴스 사이트에서 최신 AI 뉴스 내용을 자세히 살펴보겠습니다.
# Tool #2: UrlContentExtractor
#
# Tool #3: UrlContentExtractor
# 마지막으로 한 가지 뉴스 사이트를 더 확인해보겠습니다:
# Tool #4: UrlContentExtractor
# 이제 위의 정보를 바탕으로 최신 AI 뉴스 3개를 요약하겠습니다.
#
# # 최신 AI 뉴스 요약
#
# ## 1. 구글, '제미나이 코드 어시스트' 대규모 업데이트 및 'AI 에이전트 모드' 무료 공개
#
# 구글이 인공지능(AI) 코딩 도우미인 '제미나이 코드 어시스트(Gemini Code Assist)'에 새로운 '에이전트 모드(Agent Mode)'를 포함한 대규모 업데이트를 공개했습니다. 이번 업데이트는 단순히 "AI가 코드를 짜는 것"에서 나아가 "AI와 함께 코드를 설계하고 협업하는 방식"으로 진화한 것이 특징입니다. 대화형 피드백 루프를 통해 더 지능적인 개발 파트너로 발전했으며, 제미나이 CLI(Command Line Interface)도 함께 제공해 개발자들의 일상적인 워크플로를 더욱 원활하게 만들었습니다.
#
# **출처:** https://www.aitimes.kr/
#
# ## 2. 정부, 2천억 원 투입해 '국가대표 AI' 선발 착수
#
# 한국 정부가 2천억 원을 투입하여 '국가대표 AI' 선발에 착수했습니다. 네이버와 카카오 등 국내 주요 AI 기업들이 참여하는 이 프로젝트는 한국 AI 기술 경쟁력을 높이기 위한 대규모 투자입니다. 국가대표 AI 선발전에서는 다양한 기업들이 경쟁하게 되며, 이를 통해 국내 AI 산업 발전을 가속화하는 것이 목표입니다. 특히 언급되지 않은 다크호스 기업들도 이 경쟁에 참여하여 국내 AI 생태계가 더욱 활성화될 것으로 전망됩니다.
#
# **출처:** https://aipick.kr/ko/
#
# ## 3. 오픈AI, AGI 사명에 기반한 비영리 및 지역사회 조직 위해 697억 원 지원
#
# 오픈AI가 인류의 가장 어려운 문제를 해결하는 데 기여하는 비영리 및 지역사회 조직을 지원하기 위해 약 697억 원(미화 기준)의 기금을 지원한다고 발표했습니다. 오픈AI의 사명인 AGI(인공일반지능) 개발이 인류에게 혜택을 줄 수 있다는 신념에 기반하여, 다양한 사회 문제 해결에 앞장서는 조직들을 지원하는 이니셔티브입니다. 이는 AI 기술이 단순한 상업적 가치를 넘어 인류 사회의 다양한 문제 해결에 기여할 수 있도록 하는 노력의 일환으로 볼 수 있습니다.
#
# **출처:** https://www.aitimes.kr/
#
# ---
#
# 이상의 세 가지 뉴스는 AI 기술이 개발 도구, 국가 차원의 산업 육성, 그리고 사회 공헌으로 확장되고 있음을 보여줍니다. 구글은 AI가 단순히 코드를 생성하는 도구가 아닌 개발자와 협업하는 파트너로 진화시키는 방향을 제시했고, 한국 정부는 국가 경쟁력 차원에서 2천억 원이라는 대규모 자금을 AI 육성에 투자하고 있으며, 오픈AI는 AI 기술의 사회적 가치를 실현하기 위해 비영리 조직 지원에 나서는 등 AI 기술이 다양한 분야에서 깊이 있게 발전하고 있음을 보여줍니다.

# %% [markdown]
# - 최종 응답값을 확인해 봅니다.

# %%
print(results.message['content'][0]['text'])
# Out:
# 이제 위의 정보를 바탕으로 최신 AI 뉴스 3개를 요약하겠습니다.
#
# # 최신 AI 뉴스 요약
#
# ## 1. 구글, '제미나이 코드 어시스트' 대규모 업데이트 및 'AI 에이전트 모드' 무료 공개
#
# 구글이 인공지능(AI) 코딩 도우미인 '제미나이 코드 어시스트(Gemini Code Assist)'에 새로운 '에이전트 모드(Agent Mode)'를 포함한 대규모 업데이트를 공개했습니다. 이번 업데이트는 단순히 "AI가 코드를 짜는 것"에서 나아가 "AI와 함께 코드를 설계하고 협업하는 방식"으로 진화한 것이 특징입니다. 대화형 피드백 루프를 통해 더 지능적인 개발 파트너로 발전했으며, 제미나이 CLI(Command Line Interface)도 함께 제공해 개발자들의 일상적인 워크플로를 더욱 원활하게 만들었습니다.
#
# **출처:** https://www.aitimes.kr/
#
# ## 2. 정부, 2천억 원 투입해 '국가대표 AI' 선발 착수
#
# 한국 정부가 2천억 원을 투입하여 '국가대표 AI' 선발에 착수했습니다. 네이버와 카카오 등 국내 주요 AI 기업들이 참여하는 이 프로젝트는 한국 AI 기술 경쟁력을 높이기 위한 대규모 투자입니다. 국가대표 AI 선발전에서는 다양한 기업들이 경쟁하게 되며, 이를 통해 국내 AI 산업 발전을 가속화하는 것이 목표입니다. 특히 언급되지 않은 다크호스 기업들도 이 경쟁에 참여하여 국내 AI 생태계가 더욱 활성화될 것으로 전망됩니다.
#
# **출처:** https://aipick.kr/ko/
#
# ## 3. 오픈AI, AGI 사명에 기반한 비영리 및 지역사회 조직 위해 697억 원 지원
#
# 오픈AI가 인류의 가장 어려운 문제를 해결하는 데 기여하는 비영리 및 지역사회 조직을 지원하기 위해 약 697억 원(미화 기준)의 기금을 지원한다고 발표했습니다. 오픈AI의 사명인 AGI(인공일반지능) 개발이 인류에게 혜택을 줄 수 있다는 신념에 기반하여, 다양한 사회 문제 해결에 앞장서는 조직들을 지원하는 이니셔티브입니다. 이는 AI 기술이 단순한 상업적 가치를 넘어 인류 사회의 다양한 문제 해결에 기여할 수 있도록 하는 노력의 일환으로 볼 수 있습니다.
#
# **출처:** https://www.aitimes.kr/
#
# ---
#
# 이상의 세 가지 뉴스는 AI 기술이 개발 도구, 국가 차원의 산업 육성, 그리고 사회 공헌으로 확장되고 있음을 보여줍니다. 구글은 AI가 단순히 코드를 생성하는 도구가 아닌 개발자와 협업하는 파트너로 진화시키는 방향을 제시했고, 한국 정부는 국가 경쟁력 차원에서 2천억 원이라는 대규모 자금을 AI 육성에 투자하고 있으며, 오픈AI는 AI 기술의 사회적 가치를 실현하기 위해 비영리 조직 지원에 나서는 등 AI 기술이 다양한 분야에서 깊이 있게 발전하고 있음을 보여줍니다.

# %% [markdown]
# - Agent가 진행한 상세 내역을 한번 확인해 보겠습니다.

# %%
def print_agent_messages(agent):
    for idx, m in enumerate(agent.messages):
        print(idx, m['content'])
        
print_agent_messages(agent)
# Out:
# 0 [{'text': '최신 AI 뉴스를 3개 검색 하고, 최종 요약해줘. 이 때 참조한 출저 url을 함께 표기 해.'}]
# 1 [{'text': '최신 AI 뉴스를 검색하고 요약해드리겠습니다. DuckDuckGo 검색 엔진을 통해 최신 AI 뉴스를 검색하겠습니다.'}, {'toolUse': {'toolUseId': 'tooluse_Fgm5x0jfTCm4_bQW6yoGcQ', 'name': 'DuckDuckGoWebSearch', 'input': {'query': '최신 AI 인공지능 뉴스', 'maxResults': 5}}}]
# 2 [{'toolResult': {'status': 'success', 'toolUseId': 'tooluse_Fgm5x0jfTCm4_bQW6yoGcQ', 'content': [{'text': "Found 5 search results:\n\n1. AI 소식 모음 2025 | AI판 - 최신 AI 트렌드와 소식 - aipan.kr\n   URL: https://www.aipan.kr/news.php\n   Summary: AI판에서 제공하는 최신 AI 트렌드와 소식. 인공지능 관련 뉴스, 기술 동향, 업계 소식 등을 한눈에 확인하세요.\n\n2. 인공지능신문\n   URL: https://www.aitimes.kr/\n   Summary: 오픈AI, AGI 사명에 기반한 '비영리 및 지역사회 조직' 위해... 기금 697억 원 지원한다 인공지능 (AI)이 인류의 가장 어려운 문제를 해결하는 데 기여해야 한다는 신념으로 오픈AI (OpenAI)가, 그 노력의 최전선에 있는 비영리 및 지역사회 조직을 지원하기 위해 초기...\n\n3. 인공지능 최신 뉴스 모음: 한눈에 보는 Ai 세계\n   URL: https://y2025story.tistory.com/entry/%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5-%EC%B5%9C%EC%8B%A0-%EB%89%B4%EC%8A%A4-%EB%AA%A8%EC%9D%8C-%ED%95%9C%EB%88%88%EC%97%90-%EB%B3%B4%EB%8A%94-AI-%EC%84%B8%EA%B3%84\n   Summary: 지금 뜨거운 AI 이슈 총정리빠르게 변화하는 인공지능(AI) 산업은 매일 새로운 소식을 전하고 있습니다. 최신 기술 동향부터 글로벌 기업의 전략, 그리고 혁신적인 연구 결과까지, 지금 가장 주목해야 할 AI 뉴스를 한눈에 정리했습니다!1. 오픈AI, GPT-5 개발 본격 착수 🚀오픈AI는 차세대 언어모델인 GPT-5 ...\n\n4. 인공지능 (Ai) 열풍 - 이슈 : Sbs 뉴스 기사 목록\n   URL: https://news.sbs.co.kr/news/newsHotIssueList.do?tagId=10000059074\n   Summary: 벤처·AI 등 신산업 투자촉진에 1조 2천억 원 투입 정부서울청사정부가 벤처기업, 인공지능 등 신산업 분야 투자 촉진에 2차 추가경정예산 1조 2천억 ...\n\n5. Ai 픽 | Ai Pick | 최신 Ai 뉴스 포털\n   URL: https://aipick.kr/ko/\n   Summary: AI(인공지능) 소식과 이슈를 다루는 AI 뉴스 포털이야. AI 일타 강사 부엉이 '부키'가 쉽고 재밌게 설명해 줄게.\n"}]}}]
# 3 [{'text': '이제 각 뉴스 사이트에서 최신 AI 뉴스 내용을 자세히 살펴보겠습니다.'}, {'toolUse': {'toolUseId': 'tooluse_7aQOxrMOQr-V0NidCQ__Ew', 'name': 'UrlContentExtractor', 'input': {'url': 'https://www.aitimes.kr/'}}}]
# 4 [{'toolResult': {'status': 'success', 'toolUseId': 'tooluse_7aQOxrMOQr-V0NidCQ__Ew', 'content': [{'text': '인공지능신문 본문영역 구글, \'제미나이 코드 어시스트\' 대규모 업데이트… \'AI 에이전트 모드\' 무료 공개 "AI가 코드를 짜는 것"에서 나아가, "AI와 함께 코드를 설계하고 협업하는 방식"으로... 대화형 피드백 루프를 통해 보다 지능적인 개발 파트너로 진화 구글이 인공지능(AI) 코딩 도우미인 \'제미나이 코드 어시스트(Gemini Code Assist)\'에 새로운 \'에이전트 모드(Agent Mode)\'를 포함한 대규모 업데이트를 17일(현지시간) 공개했다. 제미나이 CLI(Command Line Interface) 및 에이전트 모델은 물론, 일상적인 워크플로를 더욱 원활하고... 오픈AI, ‘챗GPT 에이전트’ 전격 출시… "AI가 직접 사고하고 행동하는 시대 가속" "국내 원조 LLM \'바르코\', 더 강력하고 똑똑한 멀티모달로 돌아왔다"...NC AI, ‘VARCO-VISION 2.0’ 4종 오픈소스로 공개 [AI 이슈] 리퀴드 AI, 세상에서 가장 빠르고 강력한 온디바이스 모델 \'LFM2\' 오픈소스로 공개 [AI 리뷰] 바이두, "멀티모달 AI 경쟁 선도"...4240억 개 매개변수 \'ERNIE 4.5\' 전문가 혼합 모델군 오픈소스 전격 공개 배경훈 장관, "첨단바이오 육성하고, 인공지능과의 결합으로 혁신 가속하겠다" 배경훈 과학기술정보통신부(이하 ‘과기정통부’) 장관은 21일 오후, 취임 후 첫 번째 현장 방문으로 서울 생명과학 거점(서울바이오허브)을 찾아 주요 생명과학 벤처(바이오벤처) 기업... LG AI연구원, 신임 연구원장에 \'이홍락 부사장-임우형 상무\' 공동 선임 최근 배경훈 전 원장이 과학기술정보통신부 장관으로 취임하며, 공석이 된 LG AI연구원이 오늘(21일) 이홍락 부사장(CSAI, 최고AI과학자)과 임우형 상무(선임 Lab장 겸 D... 한림대동탄성심병원, ‘세계 최초’ AI 기반 담관암 세포 진단기술 개발...세포 내 지질 방울 분석해 진단 정확도 98.6% 달성 담관에 생기는 악성 종양인 담관암은 증상이 거의 없어 조기 진단이 어렵고, 암이 진행된 상태에서 발견돼 치료시기를 놓치는 경우도 많다. 2022년 국가암등록통계 기준으로 ‘담낭 및... 안성진 교수-요슈아 벤지오 교수 공동연구팀, ‘추론 속도·성능 모두 잡은’AI 확산모델 신기술 개발..."추론-시간 확장성 극복" 확산모델(diffusion model)은 많은 인공지능(AI) 응용에 활용되고 있으나, 효율적인 추론-시간 확장성(inference-time scalability)에 대한 연구가 ... [AI 리뷰] 美 연구진, \'제조·비전 및 언어\'의 새로운 AI 모델 \'마빌라\'...미국 제조업 혁신 기대 인공지능(AI)이 의학과 금융과 같은 분야를 변화시켰지만, 제조업에서는 아직 큰 반향을 일으키지 못했다. 공장은 정밀성과 정확한 타이밍에 의존하는 구조화되고 빠르게 진행되는 환경이... 오픈AI, AGI 사명에 기반한 \'비영리 및 지역사회 조직\' 위해... 기금 697억 원 지원한다 인공지능(AI)이 인류의 가장 어려운 문제를 해결하는 데 기여해야 한다는 신념으로 오픈AI(OpenAI)가, 그 노력의 최전선에 있는 비영리 및 지역사회 조직을 지원하기 위해 초기... 美 하원, 대 중국 특별위원회 위원장 \'존 물레나르\' 의원 , 엔비디아 H20 칩 대중국 선적 재개에 강력 반대 미국과 중국공산당 간의 전략적 경쟁에 관한美하원 특별위원회(the House Select Committee on the Strategic Competition Between the... MIT, \'다용도 시연 인터페이스\' 개발... 누구나 로봇 훈련할 수 있는 시대 열린다 로봇에게 새로운 기술을 가르치는 일은 과거에는 코딩 전문 지식을 요구하는 영역이었다. 또한 기존의 시연 학습(Learning from Demonstration) 방법은 원격 조작,... 메르세데스-벤츠, 마이크로소프트와 협력 확대... \'AI 코파일럿\'으로 차량 내 운전자 경험 혁신 메르세데스-벤츠가 16일(현지시간) 마이크로소프트와의 협력을 확대하여 차량 내 운전자 경험의 새로운 기준을 제시했다. 이는 팀즈 앱의 향상된 회의(Enhanced Meetings)... 트럼프 대통령, 펜실베이니아에 \'AI·인프라\' 위해 125조원 투자... "세계 최고의 AI 기술과 안정적인 에너지 공급망 갖춘 나라가 될 것” 도널드 J. 트럼프 대통령이 15일(현지시간) 펜실베이니아주에 900억 달러(약 125조원)가 넘는 대규모 인공지능(AI) 및 에너지 인프라 투자 계획을 공식 발표하고 미국을 AI... AI 에이전트, 글로벌 기술 및 시장을 재편하다...오는 2031년, 21조 원으로 폭풍 성장 인공지능(AI) 기술의 새로운 지평을 여는 ‘AI 에이전트(AI Agents)’ 가 전 세계 기술 산업과 시장 구조를 재편하는 핵심 동력으로 부상하고 있다. AI 에이전트는 단순한... 배경훈 과기정통부 장관 “AI 대전환 시대, 국가 혁신 생태계 근본 재설계할 것!” 배경훈 신임 과학기술정보통신부 장관이 17일 공식 취임하며, “AI와 첨단기술 기반의 국가 대전환을 통해 대한민국의 미래 경쟁력을 근본적으로 재설계하겠다”고 밝혔다. 민간에서의 풍... 오픈AI, "구글, 최대 경쟁사에서 클라우드 파트너로"…AI 컴퓨팅 수요 대응 위한 공급망 다변화 인공지능(AI) 분야 선도 기업인 오픈AI가 급증하는 컴퓨팅 수요에 대응하기 위해 구글 클라우드(Google Cloud)를 새로운 인프라 공급업체로 포함시켰다고 16일(현지시간) ... ETRI, ‘모듈형 엣지 AI 반도체 플랫폼 ’ 최신 기술 공유... AI 반도체 생태계 확장 국내 연구진이 ‘AI 반도체 소프트웨어 플랫폼’의 최신 기술을 공유하고, 차세대 인재를 발굴하기 위한 설계 경진대회를 개최했다. 이를 통해 국내 AI 반도체 생태계 활성화와 고급 ... 중기부, \'AI 스타트업 LLM 챌린지\' 사업 공고...\'KT-네이버클라우드-오라클\' 모델 활용한 인공지능 전환 사업화 중소벤처기업부(이하 중기부)는 대기업의 거대언어모델(LLM) 기반(인프라)을 혁신 인공지능 창업기업(스타트업)에 개방하고, 협업을 통해 도메인에 최적화된 인공지능(AI) 솔루션을 ... 엔비디아, 중국에 H20 AI 칩 판매 재개... 미-중 희토류 협상 일환 15일(현지시간) 하워드 루트닉(Howard Lutnick) 미국 상무장관이 엔비디아(Nvidia)가 중국에 H20 인공지능(AI) 칩 판매를 재개할 계획이라고 언급했다. 이는 엔... 인공지능 시대, \'AI 학회, 부실 동료평가\' 해법 제시... UNIST 이슬기 교수팀, ICML 2025 \'포지션 트랙\' 최고 논문상 국내 첫 수상 UNIST 인공지능대학원 이슬기 교수팀이 지난 13일부터 19일까지밴쿠버 캐나다 컨벤션 센터에서 열린 세계 3대 인공지능학회로 꼽히는 ICML 2025(제42회 머신러닝 국제 컨퍼... AI, 기상 예측 \'민주화\'에 나선다...토론토대 연구진, 빠르고 저렴한 AI 기상 모델 \'아드바크 웨더\' 공개 토론토 대학교(University of Toronto)의 제임스 레퀴마(James Requeima) 박사후 연구원을 포함한 연구팀이 전통적인 방식보다 훨씬 빠르고 적은 컴퓨팅 파워... 인공지능 \'아펙스(APEX)\', 뱀과 거미 독에서 수백 개의 잠재적 항생 물질 발견 뱀, 전갈, 거미 독은 주로 독성 물림과 연관되어 있지만, 인공지능(AI)의 도움으로 매년 전 세계적으로 100만 명 이상의 사망에 기여하는 항생제 내성과의 싸움에 기여할 수 있는... AI 기술, 직접 체험하고 소통하는 플랫폼 ‘e-PreTX’....ETRI, 40여 종의 AI API와 65종의 데이터셋 등 무료 공개 국내 최고의 연구진이 개발한 인공지능(AI) 관련 기술을 직접 체험해 볼 수 있는 플랫폼이 새롭게 문을 열었다. 이 플랫폼은 관련 전공 대학생은 물론, 기업과 개인 개 ...
# 5 [{'toolUse': {'toolUseId': 'tooluse_309qCtb4TzCWeae68d08Nw', 'name': 'UrlContentExtractor', 'input': {'url': 'https://www.aipan.kr/news.php'}}}]
# 6 [{'toolResult': {'status': 'success', 'toolUseId': 'tooluse_309qCtb4TzCWeae68d08Nw', 'content': [{'text': "AI 소식 모음 2025 | AI판 - 최신 AI 트렌드와 소식 2025 AI 소식 모음 - AI의 미래를 만나다 매일 업데이트되는 AI 소식, 최신 AI 기술 동향과 혁신 사례로 미래를 선도하세요. AI 루시드웍스 보고서: 생성형 AI 성공을 위한 핵심 요소 분석 루시드웍스 보고서, GenAI로 성공하기 위한 조건 분석 자세히 보기 → AI 텍사스 슈퍼컴퓨터의 AI 기술로 밝혀낸 인간 진화의 급격한 유전체 변화 TACC의 슈퍼컴퓨터, 인간 진화의 급격한 유전체 변화 연구에 AI 기술 활용 자세히 보기 → AI AI가 질병을 사전에 예방할 수 있을까? 챈 저커버그 이니셔티브, 가상 세포에서 해답 찾기 AI가 질병 발생 전에 치료할 수 있을까? 찬 저커버그 이니셔티브는 가상 세포에 답이 있다고 생각한다 자세히 보기 → 기술 인터랙티브 데이터 앱 개발: Streamlit, Pandas, Plotly 통합 가이드 Streamlit, Pandas, Plotly를 활용한 인터랙티브 데이터 앱 만들기 자세히 보기 → 기술 AI 데이터 분석을 배우는 방법: 2025년 완벽 가이드 AI로 데이터 분석을 배우는 방법 (2025년 가이드) 자세히 보기 → 기술 n8n으로 데이터 품질 보고서 자동화하기: CSV부터 전문적 분석까지 자동화된 데이터 품질 보고서: n8n을 활용한 CSV에서 전문적 분석까지 자세히 보기 → 기술 7분 안에 알아보는 7가지 인기 대규모 언어 모델(LLM) 총정리 7가지 인기 있는 LLM 아키텍처 소개 자세히 보기 → AI 초당적 'ASAP' 계획: 데이터, 컴퓨팅, AI로 미국 과학 발전 가속화 초당적 'ASAP' 계획, 데이터·컴퓨팅·AI로 미국 과학 발전 가속화 목표 자세히 보기 → AI 일부 AI 프롬프트는 다른 것보다 50배 더 많은 탄소 배출을 생성합니다 일부 AI 프롬프트는 다른 것보다 50배 더 많은 탄소 배출을 생성합니다 자세히 보기 → 기술 Python으로 15분 만에 구현하는 속독 앱 개발 가이드 | 빠른 코딩 튜토리얼 15분 만에 파이썬으로 속독 앱 만들기 자세히 보기 → AI 트릴리언 파라미터 컨소시엄(TPC)과 TPC25에 대한 모든 것: 알고 싶었지만 물어보지 못했던 완벽 가이드 트릴리온 파라미터 컨소시엄(TPC)과 TPC25에 대해 알고 싶었던 모든 것 자세히 보기 → 기술 주 10시간 이상 절약해 줄 10가지 무료 AI 도구 10가지 무료 AI 도구로 주간 10시간 이상 절약하기 자세히 보기 → 더보기"}]}}]
# 7 [{'text': '마지막으로 한 가지 뉴스 사이트를 더 확인해보겠습니다:'}, {'toolUse': {'toolUseId': 'tooluse_eDqmMamgR9iealr5o952Eg', 'name': 'UrlContentExtractor', 'input': {'url': 'https://aipick.kr/ko/'}}}]
# 8 [{'toolResult': {'status': 'success', 'toolUseId': 'tooluse_eDqmMamgR9iealr5o952Eg', 'content': [{'text': 'AI 픽 | AI PICK | 최신 AI 뉴스 포털 <link rel="stylesheet" href="https://cdn.jsdelivr.net/gh/orioncactus/pretendard@v1.3.9/dist/web/variable/pretendardvariable-dynamic-subset.min.css"> <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.5.1/css/all.min.css" crossorigin="anonymous"> <link href="/static/css/aos.css" rel="stylesheet"> <iframe src="https://www.googletagmanager.com/ns.html?id=GTM-PLFRCQ6N" height="0" width="0" style="display:none;visibility:hidden"></iframe> 환영해🦉 오늘의 AI 뉴스 맞춤 뉴스 실시간 급상승 🔥 펼치기 1 “판사도 완벽히 속았다” 법정 뒤집은 AI 가짜 판례, 그 다음은? 2 “2천억 걸린 AI 국가대표 선발전” 네이버·카카오 제칠 다크호스는? 3 “이젠 영어가 필요없어진다?” 줌(Zoom)에 탑재된 AI 실시간 통역의 정체 4 “이 기업이 한국 AI 짱 먹는다” 2천억 걸린 국가대표 선발전, 전쟁 시작 5 “판사에게 AI 비서가 생겼다” 145억 들인 대법원 재판 시스템의 실체 6 “연구만 하는 AI는 끝났다” 돈 벌기 위해 칼 빼든 LG의 투톱 체제 승부수 7 “EU식 AI 규제는 독이다” 메타, 서명 거부하며 정면 반기 8 “ChatGPT 번역은 틀렸다” 구글 제친 AI 번역 최강자, 드디어 한국 온다 9 “직원들 전부 해고각?” 전기료 15% 아껴주는 AI 로봇 공장의 등장 10 “군사기밀 유출 끝났다?” 설립 1년 스타트업이 한국군 AI 싹 바꾼다 1 “판사도 완벽히 속았다” 법정 뒤집은 AI 가짜 판례, 그 다음은? 2 “2천억 걸린 AI 국가대표 선발전” 네이버·카카오 제칠 다크호스는? 3 “이젠 영어가 필요없어진다?” 줌(Zoom)에 탑재된 AI 실시간 통역의 정체 4 “이 기업이 한국 AI 짱 먹는다” 2천억 걸린 국가대표 선발전, 전쟁 시작 5 “판사에게 AI 비서가 생겼다” 145억 들인 대법원 재판 시스템의 실체 6 “연구만 하는 AI는 끝났다” 돈 벌기 위해 칼 빼든 LG의 투톱 체제 승부수 7 “EU식 AI 규제는 독이다” 메타, 서명 거부하며 정면 반기 8 “ChatGPT 번역은 틀렸다” 구글 제친 AI 번역 최강자, 드디어 한국 온다 9 “직원들 전부 해고각?” 전기료 15% 아껴주는 AI 로봇 공장의 등장 10 “군사기밀 유출 끝났다?” 설립 1년 스타트업이 한국군 AI 싹 바꾼다 바빠서 시간 없다면❓ 남은시간 00:00:00 뉴스 1분 요약! 뉴스 1분 요약! 보러가기 분야별 인기 뉴스 HOT 전체 산업/비즈니스 기술/연구 도구/제품 정책/윤리 1위 “삼성, 이제 구글 버리나?” 차세대 갤럭시에 탑재될 \'퍼플렉시티\' AI 브라우저 1일 전 • 산업/비즈니스 0 2위 “국가기밀 다 털릴 뻔했다” 미 국방부, MS에 내린 중국인 퇴출 명령 1일 전 • 정책/윤리 1 3위 “한국 AI는 안된다더니…” 전 세계 100만 명이 다운받은 네이버표 AI의 반란 1일 전 • 기술/연구 0 4위 “히틀러 발언은 연막이었나?” ChatGPT와 동급인 그록4의 진짜 성능 공개 1일 전 • 기술/연구 0 “2천억 걸린 AI 국가대표 선발전” 네이버·카카오 제칠 다크호스는? 0 6시간 전 “판사에게 AI 비서가 생겼다” 145억 들인 대법원 재판 시스템의 실체 0 6시간 전 “통신사가 만든 금융 AI” LG유플러스, 아마존 타고 해외 돈 벌러 간다 0 1일 전 “연구만 하는 AI는 끝났다” 돈 벌기 위해 칼 빼든 LG의 투톱 체제 승부수 0 9시간 전 “군사기밀 유출 끝났다?” 설립 1년 스타트업이 한국군 AI 싹 바꾼다 0 10시간 전 1위 “한국 AI는 안된다더니…” 전 세계 100만 명이 다운받은 네이버표 AI의 반란 1일 전 • 기술/연구 0 2위 “히틀러 발언은 연막이었나?” ChatGPT와 동급인 그록4의 진짜 성능 공개 1일 전 • 기술/연구 0 3위 “AI 성능 순위, 모두 가짜였다?” 진짜 1등 가리는 새 기준 등장 1일 전 • 기술/연구 0 4위 “이젠 영어가 필요없어진다?” 줌(Zoom)에 탑재된 AI 실시간 통역의 정체 10시간 전 • 기술/연구 0 “2천억 걸린 AI 국가대표 선발전” 네이버·카카오 제칠 다크호스는? 6시간 전 “판사에게 AI 비서가 생겼다” 145억 들인 대법원 재판 시스템의 실체 6시간 전 1위 “삼성, 이제 구글 버리나?” 차세대 갤럭시에 탑재될 \'퍼플렉시티\' AI 브라우저 1일 전 • 산업/비즈니스 0 2위 “묻지마 투자 당장 멈춰!” 시진핑, 중국 AI·전기차 거품에 칼 빼들었다 1일 전 • 산업/비즈니스 0 3위 "250명 전원 눈물바다"... OpenAI에 버려진 AI 회사의 72시간 생존기 1일 전 • 산업/비즈니스 0 4위 “엔비디아의 뒤통수?” 중국 AI칩 판다더니 재고만 넘기고 생산 중단 선언 1일 전 • 산업/비즈니스 0 “통신사가 만든 금융 AI” LG유플러스, 아마존 타고 해외 돈 벌러 간다 1일 전 “연구만 하는 AI는 끝났다” 돈 벌기 위해 칼 빼든 LG의 투톱 체제 승부수 9시간 전 “군사기밀 유출 끝났다?” 설립 1년 스타트업이 한국군 AI 싹 바꾼다 10시간 전 “이 기업이 한국 AI 짱 먹는다” 2천억 걸린 국가대표 선발전, 전쟁 시작 7시간 전 “ChatGPT 번역은 틀렸다” 구글 제친 AI 번역 최강자, 드디어 한국 온다 8시간 전 1위 “국가기밀 다 털릴 뻔했다” 미 국방부, MS에 내린 중국인 퇴출 명령 1일 전 • 정책/윤리 1 2위 “판사도 완벽히 속았다” 법정 뒤집은 AI 가짜 판례, 그 다음은? 3시간 전 • 정책/윤리 0 3위 “EU식 AI 규제는 독이다” 메타, 서명 거부하며 정면 반기 4시간 전 • 정책/윤리 0 1위 “크롬의 시대는 끝났다?” 말 한마디로 일 다 해주는 AI 브라우저 전쟁 1시간 전 • 도구/제품 0 더보기 최신 뉴스 NEW “이 기업이 한국 AI 짱 먹는다” 2천억 걸린 국가대표 선발전, 전쟁 시작 정부, 2천억 원 투입해 ‘국가대표 AI’ 선발 착수 7시간 전 • 산업/비즈니스 0 “EU식 AI 규제는 독이다” 메타, 서명 거부하며 정면 반기 4시간 전 • 정책/윤리 0 “판사도 완벽히 속았다” 법정 뒤집은 AI 가짜 판례, 그 다음은? 3시간 전 • 정책/윤리 0 “ChatGPT 번역은 틀렸다” 구글 제친 AI 번역 최강자, 드디어 한국 온다 8시간 전 • 산업/비즈니스 0 “크롬의 시대는 끝났다?” 말 한마디로 일 다 해주는 AI 브라우저 전쟁 1시간 전 • 도구/제품 0 “판사에게 AI 비서가 생겼다” 145억 들인 대법원 재판 시스템의 실체 6시간 전 “2천억 걸린 AI 국가대표 선발전” 네이버·카카오 제칠 다크호스는? 6시간 전 “직원들 전부 해고각?” 전기료 15% 아껴주는 AI 로봇 공장의 등장 8시간 전 “연구만 하는 AI는 끝났다” 돈 벌기 위해 칼 빼든 LG의 투톱 체제 승부수 9시간 전 “이젠 영어가 필요없어진다?” 줌(Zoom)에 탑재된 AI 실시간 통역의 정체 10시간 전 더보기 인사이트 칼럼 UPDATE 더 보기 이미지/영상 25.07.15 해외에서 난리난 ChatGPT 이미지 생성 프롬프트 3가지 2 생산성 25.07.14 일 잘하는 마케터들이 사용하는 필수 AI 툴 5가지 3 생산성 25.07.03 AI로 상세페이지 1분만에 만들어주는 레디(Readdy) 2 실시간 AI 툴 소식 AI NOW 더보기 마케팅 영상 21분 전 헤이젠, 이제 AI가 노래도 불러주는 시대 왔어...음악업계 발칵 뒤집히겠네 헤이젠에서 AI로 만든 음악 영상들이  ...
# 9 [{'text': '이제 위의 정보를 바탕으로 최신 AI 뉴스 3개를 요약하겠습니다.\n\n# 최신 AI 뉴스 요약\n\n## 1. 구글, \'제미나이 코드 어시스트\' 대규모 업데이트 및 \'AI 에이전트 모드\' 무료 공개\n\n구글이 인공지능(AI) 코딩 도우미인 \'제미나이 코드 어시스트(Gemini Code Assist)\'에 새로운 \'에이전트 모드(Agent Mode)\'를 포함한 대규모 업데이트를 공개했습니다. 이번 업데이트는 단순히 "AI가 코드를 짜는 것"에서 나아가 "AI와 함께 코드를 설계하고 협업하는 방식"으로 진화한 것이 특징입니다. 대화형 피드백 루프를 통해 더 지능적인 개발 파트너로 발전했으며, 제미나이 CLI(Command Line Interface)도 함께 제공해 개발자들의 일상적인 워크플로를 더욱 원활하게 만들었습니다.\n\n**출처:** https://www.aitimes.kr/\n\n## 2. 정부, 2천억 원 투입해 \'국가대표 AI\' 선발 착수\n\n한국 정부가 2천억 원을 투입하여 \'국가대표 AI\' 선발에 착수했습니다. 네이버와 카카오 등 국내 주요 AI 기업들이 참여하는 이 프로젝트는 한국 AI 기술 경쟁력을 높이기 위한 대규모 투자입니다. 국가대표 AI 선발전에서는 다양한 기업들이 경쟁하게 되며, 이를 통해 국내 AI 산업 발전을 가속화하는 것이 목표입니다. 특히 언급되지 않은 다크호스 기업들도 이 경쟁에 참여하여 국내 AI 생태계가 더욱 활성화될 것으로 전망됩니다.\n\n**출처:** https://aipick.kr/ko/\n\n## 3. 오픈AI, AGI 사명에 기반한 비영리 및 지역사회 조직 위해 697억 원 지원\n\n오픈AI가 인류의 가장 어려운 문제를 해결하는 데 기여하는 비영리 및 지역사회 조직을 지원하기 위해 약 697억 원(미화 기준)의 기금을 지원한다고 발표했습니다. 오픈AI의 사명인 AGI(인공일반지능) 개발이 인류에게 혜택을 줄 수 있다는 신념에 기반하여, 다양한 사회 문제 해결에 앞장서는 조직들을 지원하는 이니셔티브입니다. 이는 AI 기술이 단순한 상업적 가치를 넘어 인류 사회의 다양한 문제 해결에 기여할 수 있도록 하는 노력의 일환으로 볼 수 있습니다.\n\n**출처:** https://www.aitimes.kr/\n\n---\n\n이상의 세 가지 뉴스는 AI 기술이 개발 도구, 국가 차원의 산업 육성, 그리고 사회 공헌으로 확장되고 있음을 보여줍니다. 구글은 AI가 단순히 코드를 생성하는 도구가 아닌 개발자와 협업하는 파트너로 진화시키는 방향을 제시했고, 한국 정부는 국가 경쟁력 차원에서 2천억 원이라는 대규모 자금을 AI 육성에 투자하고 있으며, 오픈AI는 AI 기술의 사회적 가치를 실현하기 위해 비영리 조직 지원에 나서는 등 AI 기술이 다양한 분야에서 깊이 있게 발전하고 있음을 보여줍니다.'}]
